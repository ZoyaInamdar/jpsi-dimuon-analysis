# %%
import uproot
import awkward as ak
import numpy as np
import matplotlib.pyplot as plt

print("libraries imported successfully")

# %%
file = uproot.open("")

# %%
print(file.keys())

# %%
tree = file["events"]
print(tree.keys())
